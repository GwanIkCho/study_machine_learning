# %% [markdown]
# ### Dimension Reduction Task02
# - 뇌암 유전자 발현 데이터 세트를 회귀 분석 하는모델

# %%
import pandas as pd

c_df = pd.read_csv('./datasets/brain_cancer.csv', low_memory=False)
c_df

# %%
c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Columns: 54677 entries, samples to AFFX-TrpnX-M_at
# dtypes: float64(54675), int64(1), object(1)
# memory usage: 54.2+ MB

# %%
c_df.type.value_counts()
# Out:
# type
# ependymoma               46
# glioblastoma             34
# medulloblastoma          22
# pilocytic_astrocytoma    15
# normal                   13
# Name: count, dtype: int64

# %%
# c_df.isna().sum().sum()
# c_df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

columns = ['type']
encoders = {}

for column in columns:
    encoder = LabelEncoder()
    result = encoder.fit_transform(c_df[column])
    c_df[column] = result
    encoders[column] = encoder.classes_

print(encoders)

# %%
c_df = c_df.drop(labels=['samples'], axis=1)

# %%
c_df.corr()['type'].sort_values(ascending=False)[1:]

# %%
from statsmodels.api import OLS

features, targets = c_df.iloc[:, 1:], c_df.iloc[:, 0]

model = OLS(targets, features)
print(model.fit().summary())

# %%
from sklearn.model_selection import train_test_split

features, targets = c_df.iloc[:, 1:], c_df.iloc[:, 0]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

train_df = pd.concat([X_train, y_train], axis=1).reset_index(drop=True)
test_df = pd.concat([X_test, y_test], axis=1).reset_index(drop=True)
display(train_df)
display(test_df)
# Out:
#      1007_s_at   1053_at     117_at     121_at  1255_g_at   1294_at   1316_at  \
# 0    11.401194  8.523019   7.103413   9.930036   5.778261  7.941297  6.692168
# 1    13.065363  8.555783   7.438600   9.777299   4.797744  8.274576  6.862205
# 2    12.381536  9.282545   9.671043   8.224457   6.017184  8.597751  6.273210
# 3    12.699958  8.800721  11.556188   9.166309   4.165891  7.923826  6.212754
# 4    12.422155  8.175979   7.239501   9.391487   4.192817  6.895597  6.245130
# ..         ...       ...        ...        ...        ...       ...       ...
# 99   12.249656  8.953047   9.870903   9.514205   7.035351  7.732715  6.262403
# 100  12.786550  7.570790   7.518998   9.297586   4.040876  8.779409  6.626602
# 101  12.506887  8.855623   8.773573   8.574727   4.131700  7.666310  7.545845
# 102  13.380570  7.186360   7.306096  10.007127   5.507750  8.631605  6.951237
# 103  12.654797  9.250091  11.031744   8.795852   4.464613  8.222089  6.351991
#
#       1320_at  1405_i_at   1431_at  ...  AFFX-r2-Ec-bioD-5_at  \
# 0    7.758998   6.749174  5.070654  ...             11.940182
# 1    7.521131   6.292229  5.323437  ...             11.154223
# 2    5.767105   7.069769  4.946979  ...             11.703560
# 3    6.866387   5.405628  5.279579  ...             11.169317
# 4    5.917008   5.806313  5.117815  ...             12.550633
# ..        ...        ...       ...  ...                   ...
# 99   6.518894   5.766345  5.376257  ...             11.661944
# 100  7.308385   5.129121  5.649770  ...             10.743047
# 101  5.972713   5.907529  6.405782  ...             11.722468
# 102  6.474038   8.646862  5.589963  ...             12.344592
# 103  6.260848   6.874224  5.782028  ...             11.787211
#
#      AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  \
# 0              13.646216            13.597221        5.216630        4.678024
# 1              13.433052            13.138487        5.313133        5.145531
# 2              13.924516            13.473175        4.883626        4.461374
# 3              13.751442            13.803646        4.892677        4.773806
# 4              13.297571            13.464840        5.232236        4.689635
# ..                   ...                  ...             ...             ...
# 99             13.687183            13.409215        5.448873        4.982380
# 100            13.619982            13.675089        4.823342        4.720278
# 101            13.879072            13.529125        5.028780        4.593898
# 102            13.909623            13.993160        5.169097        4.972834
# 103            13.839176            13.512018        5.030119        4.600989
#
#      AFFX-ThrX-M_at  AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  AFFX-TrpnX-M_
# 17        4.547821         4.854368         4.852114         5.436919     3
# 18        3.878855         3.680103         4.726784         4.564637     4
# 19        3.903365         3.432622         4.584166         4.635494     1
# 20        3.842123         3.632589         4.718510         4.383670     1
# 21        3.789435         3.570607         4.389063         4.516023     0
# 22        3.942146         4.306064         4.841028         4.758554     0
# 23        4.010441         3.866341         4.471244         4.766970     3
# 24        3.944956         3.597369         4.388004         4.360662     1
# 25        3.864562         3.610794         4.590739         4.709032     2
#
# [26 rows x 54676 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=1)

lda_train = lda.fit_transform(train_df.iloc[:, :-1], train_df.iloc[:, -1])
lda_test = lda.fit_transform(test_df.iloc[:, :-1], test_df.iloc[:, -1])

print(lda_train.shape, lda_test.shape)
# Out:
# (104, 1) (26, 1)

# %%
lda_columns = [f'lda{i + 1}' for i in range(lda_train.shape[1])]
lda_train_df = pd.DataFrame(lda_train, columns=lda_columns)
lda_train_df.loc[:, 'target'] = train_df['type']

lda_columns = [f'lda{i + 1}' for i in range(lda_test.shape[1])]
lda_test_df = pd.DataFrame(lda_test, columns=lda_columns)
lda_test_df.loc[:, 'target'] = test_df['type']

# %%
display(lda_train_df)
display(lda_test_df)
# Out:
#          lda1  target
# 0   -1.916445       2
# 1   -1.104412       4
# 2    0.777787       1
# 3    2.208191       0
# 4   -0.575613       1
# ..        ...     ...
# 99  -0.125179       1
# 100  3.303627       0
# 101  2.799285       0
# 102 -0.665863       4
# 103  1.306588       1
#
# [104 rows x 2 columns]
#         lda1  target
# 0  -0.130990       2
# 1  -0.942928       1
# 2   0.711590       0
# 3   0.039883       0
# 4   0.671258       0
# 5   1.047829       1
# 6  -0.225348       1
# 7  -0.368911       4
# 8   3.345018       0
# 9   1.042167       0
# 10  0.623461       4
# 11 -0.891619       2
# 12 -0.852998       3
# 13  1.734173       1
# 14  0.952694       0
# 15 -0.461417       2
# 16 -0.032700       0
# 17 -3.878552       3
# 18 -0.248424       4
# 19  1.201733       1
# 20  0.820050       1
# 21  0.381226       0
# 22 -0.084267       0
# 23 -2.746469       3
# 24 -0.715443       1
# 25 -0.991017       2

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

features, targets = lda_train_df.iloc[:, :-1], lda_train_df.iloc[:, -1]
parameters = {'max_depth': [2,3,4], 'min_samples_split': [10, 50, 100]}

rfc = RandomForestClassifier()
# import sklearn
# sklearn.metrics.SCORERS.keys()
g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=5, return_train_score=True, scoring='accuracy')
g_rfc.fit(features, targets)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 3, 4],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='accuracy')

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                        params  mean_test_score  \
# 0   {'max_depth': 2, 'min_samples_split': 10}         0.721905
# 1   {'max_depth': 2, 'min_samples_split': 50}         0.586190
# 2  {'max_depth': 2, 'min_samples_split': 100}         0.355714
# 3   {'max_depth': 3, 'min_samples_split': 10}         0.760000
# 4   {'max_depth': 3, 'min_samples_split': 50}         0.586190
# 5  {'max_depth': 3, 'min_samples_split': 100}         0.355714
# 6   {'max_depth': 4, 'min_samples_split': 10}         0.731429
# 7   {'max_depth': 4, 'min_samples_split': 50}         0.586190
# 8  {'max_depth': 4, 'min_samples_split': 100}         0.355714
#
#    rank_test_score
# 0                3
# 1                4
# 2                7
# 3                1
# 4                4
# 5                7
# 6                2
# 7                4
# 8                7
